# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pd.read_csv(r"C:\nos\my-spark\input\students.csv")
# Out:
#     张祥德  RB17101  RB171  男  1997-02-10  11122223333  河南省郑州市1号  88
# 0   冯成刚  RB17102  RB171  女  1996-10-01  18837110115  河南省洛阳市2号  86
# 1   卢伟兴  RB17103  RB171  男  1998-08-02  19999228822  河南省开封市3号  95
# 2   杨飞龙  RB17104  RB171  男  1996-08-09  13322554455  河南省安阳市4号  91
# 3   姜松林  RB17201  RB172  女  1997-01-03  13688552244  河南省鹤壁市1号  75
# 4    高飞  RB17202  RB172  男  1996-08-27  13522114455  河南省新乡市2号  68
# 5    何桦  RB17203  RB172  女  1997-12-20  13566998855  河南省焦作市3号  84
# 6   高天阳  RB17204  RB172  男  1999-11-08  13688446622  河南省濮阳市4号  77
# 7   周存富  RB17301  RB173  男  1996-05-28  13699552658  河南省许昌市1号  93
# 8    罗鹏  RB17302  RB173  男  1998-03-02  13365298741  河南省漯河市2号  85
# 9   宋立昌  RB17401  RB174  男  1995-05-28  13596325874  河南省南阳市3号  81
# 10  杨国胜  RB17402  RB174  男  1996-03-02  13256987456  河南省信阳市4号  91
# 11  徐子文  RB17403  RB174  男  1998-05-28  13523654789  河南省周口市5号  85
# 12   马彦  RB17404  RB174  女  1997-03-02  13526845962  河南省郑州市6号  73

# %%
pd.read_parquet(r"C:\nos\my-spark\input\students.parquet")
# Out:
#    name       no    cls gender    birthday        phone       loc
# 0   张祥德  RB17101  RB171      男  1997-02-10  11122223333  河南省郑州市1号
# 1   冯成刚  RB17102  RB171      女  1996-10-01  18837110115  河南省洛阳市2号
# 2   卢伟兴  RB17103  RB171      男  1998-08-02  19999228822  河南省开封市3号
# 3   杨飞龙  RB17104  RB171      男  1996-08-09  13322554455  河南省安阳市4号
# 4   姜松林  RB17201  RB172      女  1997-01-03  13688552244  河南省鹤壁市1号
# 5    高飞  RB17202  RB172      男  1996-08-27  13522114455  河南省新乡市2号
# 6    何桦  RB17203  RB172      女  1997-12-20  13566998855  河南省焦作市3号
# 7   高天阳  RB17204  RB172      男  1999-11-08  13688446622  河南省濮阳市4号
# 8   周存富  RB17301  RB173      男  1996-05-28  13699552658  河南省许昌市1号
# 9    罗鹏  RB17302  RB173      男  1998-03-02  13365298741  河南省漯河市2号
# 10  宋立昌  RB17401  RB174      男  1995-05-28  13596325874  河南省南阳市3号
# 11  杨国胜  RB17402  RB174      男  1996-03-02  13256987456  河南省信阳市4号
# 12  徐子文  RB17403  RB174      男  1998-05-28  13523654789  河南省周口市5号
# ...

# %%
pd.read_json(r"C:\nos\my-spark\input\students2.json")
# Out:
#    name       no    cls gender    birthday        phone       loc      no1  \
# 0   张祥德  RB17101  RB171      男  1997-02-10  11122223333  河南省郑州市1号      NaN
# 1   冯成刚  RB17102  RB171      女  1996-10-01  18837110115  河南省洛阳市2号      NaN
# 2   卢伟兴  RB17103  RB171      男  1998-08-02  19999228822  河南省开封市3号      NaN
# 3   杨飞龙  RB17104  RB171      男  1996-08-09  13322554455  河南省安阳市4号      NaN
# 4   姜松林  RB17201  RB172      女  1997-01-03  13688552244  河南省鹤壁市1号      NaN
# 5    高飞      NaN  RB172      男  1996-08-27  13522114455  河南省新乡市2号  RB17202
# 6    何桦  RB17203  RB172      女  1997-12-20  13566998855  河南省焦作市3号      NaN
# 7   高天阳  RB17204  RB172      男  1999-11-08  13688446622  河南省濮阳市4号      NaN
# 8   周存富  RB17301  RB173      男         NaN  13699552658  河南省许昌市1号      NaN
# 9    罗鹏  RB17302  RB173      男  1998-03-02  13365298741  河南省漯河市2号      NaN
# 10  宋立昌  RB17401  RB174      男  1995-05-28  13596325874  河南省南阳市3号      NaN
# ...

# %%
pd.read_orc(r"C:\nos\my-spark\input\students.orc")
# Out:
# ---------------------------------------------------------------------------
# ArrowException                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pd.read_orc(r"C:\nos\my-spark\input\students.orc")
#
# File C:\venv\torch\Lib\site-packages\pandas\io\orc.py:117, in read_orc(path, columns, dtype_backend, filesystem, **kwargs)
#     114         except (TypeError, pa.ArrowInvalid):
#     115             pass
# --> 117     pa_table = orc.read_table(
#     118         source=source, columns=columns, filesystem=filesystem, **kwargs
#     119     )
#     120 if dtype_backend is not lib.no_default:
#     121     if dtype_backend == "pyarrow":
#
# File C:\venv\torch\Lib\site-packages\pyarrow\orc.py:308, in read_table(source, columns, filesystem)
#     306     result = ORCFile(source).read().select(columns)
#     307 else:
# --> 308     result = ORCFile(source).read(columns=columns)
#     310 return result
#
# ...
